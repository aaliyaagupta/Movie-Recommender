# %% [markdown]
# <a href="https://colab.research.google.com/github/aaliyaagupta/Movie-Recommender/blob/main/movierecommipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import pandas as pd
import numpy as np
import re
import nltk
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("/IMDB_Top250movies2_OMDB_Detailed.csv")
df.head()
# Out:
#    Unnamed: 0                     Title  Year     Rated     Released  Runtime  \
# 0           1  The Shawshank Redemption  1994         R  14 Oct 1994  142 min
# 1           2             The Godfather  1972         R  24 Mar 1972  175 min
# 2           3    The Godfather: Part II  1974         R  20 Dec 1974  202 min
# 3           4           The Dark Knight  2008     PG-13  18 Jul 2008  152 min
# 4           5              12 Angry Men  1957  APPROVED  01 Apr 1957   96 min
#
#                   Genre              Director  \
# 0          Crime, Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2          Crime, Drama  Francis Ford Coppola
# 3  Action, Crime, Drama     Christopher Nolan
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0  Stephen King (short story "Rita Hayworth and S...
# 1  Mario Puzo (screenplay), Francis Ford Coppola ...
# 2  Francis Ford Coppola (screenplay), Mario Puzo ...
# 3  Jonathan Nolan (screenplay), Christopher Nolan...
# 4  Reginald Rose (story), Reginald Rose (screenplay)
#
#                                               Actors  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Marlon Brando, Al Pacino, James Caan, Richard ...
# 2  Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 3  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
#
#                                                 Plot  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  The early life and career of Vito Corleone in ...
# 3  When the menace known as the Joker emerges fro...
# 4  A jury holdout attempts to prevent a miscarria...
#
#                                      Language  Country  \
# 0                                     English      USA
# 1                     English, Italian, Latin      USA
# 2  English, Italian, Spanish, Latin, Sicilian      USA
# 3                           English, Mandarin  USA, UK
# 4                                     English      USA
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. Another 19 wins & 30 n...
# 1    Won 3 Oscars. Another 23 wins & 27 nominations.
# 2    Won 6 Oscars. Another 10 wins & 20 nominations.
# 3  Won 2 Oscars. Another 151 wins & 153 nominations.
# 4  Nominated for 3 Oscars. Another 16 wins & 8 no...
#
#                                               Poster           Ratings.Source  \
# 0  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 1  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 2  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 3  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 4  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
#
#   Ratings.Value  Metascore  imdbRating  imdbVotes     imdbID   Type  \
# 0        9.3/10       80.0         9.3    1825626  tt0111161  movie
# 1        9.2/10      100.0         9.2    1243444  tt0068646  movie
# 2        9.0/10       85.0         9.0     856870  tt0071562  movie
# 3        9.0/10       82.0         9.0    1802351  tt0468569  movie
# 4        8.9/10       96.0         8.9     494215  tt0050083  movie
#
#    tomatoMeter  tomatoImage  tomatoRating  tomatoReviews  tomatoFresh  \
# 0          NaN          NaN           NaN            NaN          NaN
# 1          NaN          NaN           NaN            NaN          NaN
# 2          NaN          NaN           NaN            NaN          NaN
# 3          NaN          NaN           NaN            NaN          NaN
# 4          NaN          NaN           NaN            NaN          NaN
#
#    tomatoRotten  tomatoConsensus  tomatoUserMeter  tomatoUserRating  \
# 0           NaN              NaN              NaN               NaN
# 1           NaN              NaN              NaN               NaN
# 2           NaN              NaN              NaN               NaN
# 3           NaN              NaN              NaN               NaN
# 4           NaN              NaN              NaN               NaN
#
#    tomatoUserReviews                                          tomatoURL  \
# 0                NaN  http://www.rottentomatoes.com/m/shawshank_rede...
# 1                NaN         http://www.rottentomatoes.com/m/godfather/
# 2                NaN  http://www.rottentomatoes.com/m/godfather_part...
# 3                NaN   http://www.rottentomatoes.com/m/the_dark_knight/
# 4                NaN  http://www.rottentomatoes.com/m/1000013-12_ang...
#
#            DVD     BoxOffice                       Production  \
# 0  27 Jan 1998           NaN                Columbia Pictures
# 1  09 Oct 2001           NaN               Paramount Pictures
# 2  24 May 2005           NaN               Paramount Pictures
# 3  09 Dec 2008  $533,316,061  Warner Bros. Pictures/Legendary
# 4  06 Mar 2001           NaN             Criterion Collection
#
#                                              Website  Response
# 0                                                NaN      True
# 1                        http://www.thegodfather.com      True
# 2                       http://www.thegodfather.com/      True
# 3               http://thedarkknight.warnerbros.com/      True
# 4  http://www.criterion.com/films/27871-12-angry-men      True

# %%
len(df)
# Out:
# 250

# %%
df['Plot'][0]
# Out:
# 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.'

# %%
df['clean_plot'] = df['Plot'].str.lower()
df['clean_plot'] = df['clean_plot'].apply(lambda x: re.sub('[^a-zA-Z]', ' ', x))
df['clean_plot'] = df['clean_plot'].apply(lambda x: re.sub('\s+', ' ', x)) 
df['clean_plot']
# Out:
# 0      two imprisoned men bond over a number of years...
# 1      the aging patriarch of an organized crime dyna...
# 2      the early life and career of vito corleone in ...
# 3      when the menace known as the joker emerges fro...
# 4      a jury holdout attempts to prevent a miscarria...
#                              ...
# 245    blacksmith will turner teams up with eccentric...
# 246    a former child star torments her paraplegic si...
# 247    travis henderson an aimless drifter who has be...
# 248    desperate measures are taken by a man who trie...
# 249    a stranger in the city asks questions no one h...
# Name: clean_plot, Length: 250, dtype: object

# %%
# tokenize the sentence
df['clean_plot'] = df['clean_plot'].apply(lambda x: nltk.word_tokenize(x))
df['clean_plot']
# Out:
# 0      [two, imprisoned, men, bond, over, a, number, ...
# 1      [the, aging, patriarch, of, an, organized, cri...
# 2      [the, early, life, and, career, of, vito, corl...
# 3      [when, the, menace, known, as, the, joker, eme...
# 4      [a, jury, holdout, attempts, to, prevent, a, m...
#                              ...
# 245    [blacksmith, will, turner, teams, up, with, ec...
# 246    [a, former, child, star, torments, her, parapl...
# 247    [travis, henderson, an, aimless, drifter, who,...
# 248    [desperate, measures, are, taken, by, a, man, ...
# 249    [a, stranger, in, the, city, asks, questions, ...
# Name: clean_plot, Length: 250, dtype: object

# %%
stop_words = nltk.corpus.stopwords.words('english')
plot = []
for sentence in df['clean_plot']:
    temp = []
    for word in sentence:
        if word not in stop_words and len(word) >= 3:
            temp.append(word)
    plot.append(temp)
plot
# Out:
# [['two',
#   'imprisoned',
#   'men',
#   'bond',
#   'number',
#   'years',
#   'finding',
#   'solace',
#   'eventual',
#   'redemption',
#   'acts',
#   'common',
#   'decency'],
#  ['aging',
#   'patriarch',
#   'organized',
#   'crime',
#   'dynasty',
#   'transfers',
#   'control',
#   'clandestine',
#   'empire',
#   'reluctant',
#   'son'],
#  ['early',
#   'life',
#   'career',
#   'vito',
#   'corleone',
#   'new',
#   'york',
#   'portrayed',
#   'son',
#   'michael',
#   'expands',
#   'tightens',
#   'grip',
#   'family',
#   'crime',
#   'syndicate'],
#  ['menace',
#   'known',
#   'joker',
#   'emerges',
#   'mysterious',
#   'past',
#   'wreaks',
#   'havoc',
#   'chaos',
#   'people',
#   'gotham',
#   'dark',
#   'knight',
#   'must',
#   'accept',
#   'one',
#   'greatest',
#   'psychological',
#   'physical',
#   'tests',
#   'ability',
#   'fight',
#   'injustice'],
#  ['jury',
#   'holdout',
#   'attempts',
#   'prevent',
#   'miscarriage',
#   'justice',
#   'forcing',
#   'colleagues',
#   'reconsider',
#   'evidence'],
#  ['german',
#   'occupied',
#   'poland',
#   'world',
#   'war',
#   'oskar',
#   'schindler',
#   'gradually',
#   'becomes',
#   'concerned',
#   'jewish',
#   'workforce',
#   'witnessing',
#   'persecution',
#   'nazi',
#   'germans'],
#  ['lives',
#   'two',
#   'mob',
#   'hit',
#   'men',
#   'boxer',
#   'gangster',
#   'wife',
#   'pair',
#   'diner',
#   'bandits',
#   'intertwine',
#   'four',
#   'tales',
#   'violence',
#   'redemption'],
#  ['gandalf',
#   'aragorn',
#   'lead',
#   'world',
#   'men',
#   'sauron',
#   'army',
#   'draw',
#   'gaze',
#   'frodo',
#   'sam',
#   'approach',
#   'mount',
#   'doom',
#   'one',
#   'ring'],
#  ['bounty',
#   'hunting',
#   'scam',
#   'joins',
#   'two',
#   'men',
#   'uneasy',
#   'alliance',
#   'third',
#   'race',
#   'find',
#   'fortune',
#   'gold',
#   'buried',
#   'remote',
#   'cemetery'],
#  ['insomniac',
#   'office',
#   'worker',
#   'looking',
#   'way',
#   'change',
#   'life',
#   'crosses',
#   'paths',
#   'devil',
#   'may',
#   'care',
#   'soap',
#   'maker',
#   'forming',
#   'underground',
#   'fight',
#   'club',
#   'evolves',
#   'something',
#   'much',
#   'much'],
#  ['meek',
#   'hobbit',
#   'shire',
#   'eight',
#   'companions',
#   'set',
#   'journey',
#   'destroy',
#   'powerful',
#   'one',
#   'ring',
#   'save',
#   'middle',
#   'earth',
#   'dark',
#   'lord',
#   'sauron'],
#  ['intelligent',
#   'forrest',
#   'gump',
#   'accidentally',
#   'present',
#   'many',
#   'historic',
#   'moments',
#   'true',
#   'love',
#   'jenny',
#   'curran',
#   'eludes'],
#  ['rebels',
#   'overpowered',
#   'empire',
#   'newly',
#   'established',
#   'base',
#   'luke',
#   'skywalker',
#   'begins',
#   'jedi',
#   'training',
#   'master',
#   'yoda',
#   'friends',
#   'accept',
#   'shelter',
#   'questionable',
#   'ally',
#   'darth',
#   'vader',
#   'hunts',
#   'plan',
#   'capture',
#   'luke'],
#  ['thief',
#   'steals',
#   'corporate',
#   'secrets',
#   'use',
#   'dream',
#   'sharing',
#   'technology',
#   'given',
#   'inverse',
#   'task',
#   'planting',
#   'idea',
#   'mind',
#   'ceo'],
#  ['frodo',
#   'sam',
#   'edge',
#   'closer',
#   'mordor',
#   'help',
#   'shifty',
#   'gollum',
#   'divided',
#   'fellowship',
#   'makes',
#   'stand',
#   'sauron',
#   'new',
#   'ally',
#   'saruman',
#   'hordes',
#   'isengard'],
#  ['criminal',
#   'pleads',
#   'insanity',
#   'getting',
#   'trouble',
#   'mental',
#   'institution',
#   'rebels',
#   'oppressive',
#   'nurse',
#   'rallies',
#   'scared',
#   'patients'],
#  ['story',
#   'henry',
#   'hill',
#   'life',
#   'teen',
#   'years',
#   'years',
#   'mafia',
#   'covering',
#   'relationship',
#   'wife',
#   'karen',
#   'hill',
#   'mob',
#   'partners',
#   'jimmy',
#   'conway',
#   'tommy',
#   'devitto',
#   'italian',
#   'american',
#   'crime',
#   'syndicate'],
#  ['computer',
#   'hacker',
#   'learns',
#   'mysterious',
#   'rebels',
#   'true',
#   'nature',
#   'reality',
#   'role',
#   'war',
#   'controllers'],
#  ['poor',
#   'village',
#   'attack',
#   'bandits',
#   'recruits',
#   'seven',
#   'unemployed',
#   'samurai',
#   'help',
#   'defend'],
#  ['luke',
#   'skywalker',
#   'joins',
#   'forces',
#   'jedi',
#   'knight',
#   'cocky',
#   'pilot',
#   'wookiee',
#   'two',
#   'droids',
#   'save',
#   'galaxy',
#   'empire',
#   'world',
#   'destroying',
#   'battle',
#   'station',
#   'also',
#   'attempting',
#   'rescue',
#   'princess',
#   'leia',
#   'evil',
#   'darth',
#   'vader'],
#  ['two',
#   'boys',
#   'growing',
#   'violent',
#   'neighborhood',
#   'rio',
#   'janeiro',
#   'take',
#   'different',
#   'paths',
#   'one',
#   'becomes',
#   'photographer',
#   'drug',
#   'dealer'],
#  ['two',
#   'detectives',
#   'rookie',
#   'veteran',
#   'hunt',
#   'serial',
#   'killer',
#   'uses',
#   'seven',
#   'deadly',
#   'sins',
#   'motives'],
#  ['young',
#   'cadet',
#   'must',
#   'confide',
#   'incarcerated',
#   'manipulative',
#   'killer',
#   'receive',
#   'help',
#   'catching',
#   'another',
#   'serial',
#   'killer',
#   'skins',
#   'victims'],
#  ['angel',
#   'sent',
#   'heaven',
#   'help',
#   'desperately',
#   'frustrated',
#   'businessman',
#   'showing',
#   'life',
#   'would',
#   'like',
#   'never',
#   'existed'],
#  ['open',
#   'minded',
#   'jewish',
#   'librarian',
#   'son',
#   'become',
#   'victims',
#   'holocaust',
#   'uses',
#   'perfect',
#   'mixture',
#   'humor',
#   'imagination',
#   'protect',
#   'son',
#   'dangers',
#   'around',
#   'camp'],
#  ['sole',
#   'survivor',
#   'tells',
#   'twisty',
#   'events',
#   'leading',
#   'horrific',
#   'gun',
#   'battle',
#   'boat',
#   'began',
#   'five',
#   'criminals',
#   'met',
#   'seemingly',
#   'random',
#   'police',
#   'lineup'],
#  ['mathilda',
#   'year',
#   'old',
#   'girl',
#   'reluctantly',
#   'taken',
#   'professional',
#   'assassin',
#   'family',
#   'murdered',
#   'mathilda',
#   'form',
#   'unusual',
#   'relationship',
#   'becomes',
#   'prot',
#   'learns',
#   'assassin',
#   'trade'],
#  ['following',
#   'normandy',
#   'landings',
#   'group',
#   'soldiers',
#   'behind',
#   'enemy',
#   'lines',
#   'retrieve',
#   'paratrooper',
#   'whose',
#   'brothers',
#   'killed',
#   'action'],
#  ['family',
#   'move',
#   'suburbs',
#   'sullen',
#   'year',
#   'old',
#   'girl',
#   'wanders',
#   'world',
#   'ruled',
#   'gods',
#   'witches',
#   'spirits',
#   'humans',
#   'changed',
#   'beasts'],
#  ['mysterious',
#   'stranger',
#   'harmonica',
#   'joins',
#   'forces',
#   'notorious',
#   'desperado',
#   'protect',
#   'beautiful',
#   'widow',
#   'ruthless',
#   'assassin',
#   'working',
#   'railroad'],
#  ['former',
#   'neo',
#   'nazi',
#   'skinhead',
#   'tries',
#   'prevent',
#   'younger',
#   'brother',
#   'going',
#   'wrong',
#   'path'],
#  ['team',
#   'explorers',
#   'travel',
#   'wormhole',
#   'space',
#   'attempt',
#   'ensure',
#   'humanity',
#   'survival'],
#  ['phoenix',
#   'secretary',
#   'embezzles',
#   'employer',
#   'client',
#   'goes',
#   'run',
#   'checks',
#   'remote',
#   'motel',
#   'run',
#   'young',
#   'man',
#   'domination',
#   'mother'],
#  ['casablanca',
#   'december',
#   'cynical',
#   'american',
#   'expatriate',
#   'encounters',
#   'former',
#   'lover',
#   'unforeseen',
#   'complications'],
#  ['aid',
#   'wealthy',
#   'erratic',
#   'tippler',
#   'dewy',
#   'eyed',
#   'tramp',
#   'fallen',
#   'love',
#   'sightless',
#   'flower',
#   'girl',
#   'accumulates',
#   'money',
#   'able',
#   'help',
#   'medically'],
#  ['lives',
#   'guards',
#   'death',
#   'row',
#   'affected',
#   'one',
#   'charges',
#   'black',
#   'man',
#   'accused',
#   'child',
#   'murder',
#   'rape',
#   'yet',
#   'mysterious',
#   'gift'],
#  ['becomes',
#   'quadriplegic',
#   'paragliding',
#   'accident',
#   'aristocrat',
#   'hires',
#   'young',
#   'man',
#   'projects',
#   'caregiver'],
#  ['tramp',
#   'struggles',
#   'live',
#   'modern',
#   'industrial',
#   'society',
#   'help',
#   'young',
#   'homeless',
#   'woman'],
#  ['archaeologist',
#   'adventurer',
#   'indiana',
#   'jones',
#   'hired',
#   'government',
#   'find',
#   'ark',
#   'covenant',
#   'nazis'],
#  ['wheelchair',
#   'bound',
#   'photographer',
#   'spies',
#   'neighbours',
#   'apartment',
#   'window',
#   'becomes',
#   'convinced',
#   'one',
#   'committed',
#   'murder'],
#  ['polish',
#   'jewish',
#   'musician',
#   'struggles',
#   'survive',
#   'destruction',
#   'warsaw',
#   'ghetto',
#   'world',
#   'war'],
#  ['undercover',
#   'cop',
#   'mole',
#   'police',
#   'attempt',
#   'identify',
#   'infiltrating',
#   'irish',
#   'gang',
#   'south',
#   'boston'],
#  ['cyborg',
#   'identical',
#   'one',
#   'failed',
#   'kill',
#   'sarah',
#   'connor',
#   'must',
#   'protect',
#   'ten',
#   'year',
#   'old',
#   'son',
#   'john',
#   'connor',
#   'advanced',
#   'cyborg'],
#  ['marty',
#   'mcfly',
#   'year',
#   'old',
#   'high',
#   'school',
#   'student',
#   'accidentally',
#   'sent',
#   'years',
#   'past',
#   'time',
#   'traveling',
#   'delorean',
#   'invented',
#   'close',
#   'friend',
#   'maverick',
#   'scientist',
#   'doc',
#   'brown'],
#  ['promising',
#   'young',
#   'drummer',
#   'enrolls',
#   'cut',
#   'throat',
#   'music',
#   'conservatory',
#   'dreams',
#   'greatness',
#   'mentored',
#   'instructor',
#   'stop',
#   'nothing',
#   'realize',
#   'student',
#   'potential'],
#  ['roman',
#   'general',
#   'betrayed',
#   'family',
#   'murdered',
#   'emperor',
#   'corrupt',
#   'son',
#   'comes',
#   'rome',
#   'gladiator',
#   'seek',
#   'revenge'],
#  ['man',
#   'juggles',
#   'searching',
#   'wife',
#   'murderer',
#   'keeping',
#   'short',
#   'term',
#   'memory',
#   'loss',
#   'obstacle'],
#  ['two',
#   'stage',
#   'magicians',
#   'engage',
#   'competitive',
#   'one',
#   'upmanship',
#   'attempt',
#   'create',
#   'ultimate',
#   'stage',
#   'illusion'],
#  ['lion',
#   'cub',
#   'future',
#   'king',
#   'simba',
#   'searches',
#   'identity',
#   'eagerness',
#   'please',
#   'others',
#   'penchant',
#   'testing',
#   'boundaries',
#   'sometimes',
#   'gets',
#   'trouble'],
#  ['vietnam',
#   'war',
#   'captain',
#   'willard',
#   'sent',
#   'dangerous',
#   'mission',
#   'cambodia',
#   'assassinate',
#   'renegade',
#   'colonel',
#   'set',
#   'god',
#   'among',
#   'local',
#   'tribe'],
#  ['space',
#   'merchant',
#   'vessel',
#   'perceives',
#   'unknown',
#   'transmission',
#   'distress',
#   'call',
#   'landing',
#   'source',
#   'moon',
#   'finds',
#   'one',
#   'crew',
#   'attacked',
#   'mysterious',
#   'life',
#   'form',
#   'soon',
#   'realize',
#   'life',
#   'cycle',
#   'merely',
#   'begun'],
#  ['screenwriter',
#   'hired',
#   'rework',
#   'faded',
#   'silent',
#   'film',
#   'star',
#   'script',
#   'find',
#   'developing',
#   'dangerous',
#   'relationship'],
#  ['insane',
#   'general',
#   'triggers',
#   'path',
#   'nuclear',
#   'holocaust',
#   'war',
#   'room',
#   'full',
#   'politicians',
#   'generals',
#   'frantically',
#   'try',
#   'stop'],
#  ['dictator',
#   'adenoid',
#   'hynkel',
#   'tries',
#   'expand',
#   'empire',
#   'poor',
#   'jewish',
#   'barber',
#   'tries',
#   'avoid',
#   'persecution',
#   'hynkel',
#   'regime'],
#  ['filmmaker',
#   'recalls',
#   'childhood',
#   'fell',
#   'love',
#   'movies',
#   'village',
#   'theater',
#   'formed',
#   'deep',
#   'friendship',
#   'theater',
#   'projectionist'],
#  ['east',
#   'berlin',
#   'agent',
#   'secret',
#   'police',
#   'conducting',
#   'surveillance',
#   'writer',
#   'lover',
#   'finds',
#   'becoming',
#   'increasingly',
#   'absorbed',
#   'lives'],
#  ['young',
#   'boy',
#   'little',
#   'sister',
#   'struggle',
#   'survive',
#   'japan',
#   'world',
#   'war'],
#  ['refusing',
#   'attack',
#   'enemy',
#   'position',
#   'general',
#   'accuses',
#   'soldiers',
#   'cowardice',
#   'commanding',
#   'officer',
#   'must',
#   'defend'],
#  ['help',
#   'german',
#   'bounty',
#   'hunter',
#   'freed',
#   'slave',
#   'sets',
#   'rescue',
#   'wife',
#   'brutal',
#   'mississippi',
#   'plantation',
#   'owner'],
#  ['family',
#   'heads',
#   'isolated',
#   'hotel',
#   'winter',
#   'evil',
#   'spiritual',
#   'presence',
#   'influences',
#   'father',
#   'violence',
#   'psychic',
#   'son',
#   'sees',
#   'horrific',
#   'forebodings',
#   'past',
#   'future'],
#  ['distant',
#   'future',
#   'small',
#   'waste',
#   'collecting',
#   'robot',
#   'inadvertently',
#   'embarks',
#   'space',
#   'journey',
#   'ultimately',
#   'decide',
#   'fate',
#   'mankind'],
#  ['sexually',
#   'frustrated',
#   'suburban',
#   'father',
#   'mid',
#   'life',
#   'crisis',
#   'becoming',
#   'infatuated',
#   'daughter',
#   'best',
#   'friend'],
#  ['eight',
#   'years',
#   'joker',
#   'reign',
#   'anarchy',
#   'dark',
#   'knight',
#   'help',
#   'enigmatic',
#   'selina',
#   'forced',
#   'imposed',
#   'exile',
#   'save',
#   'gotham',
#   'city',
#   'edge',
#   'total',
#   'annihilation',
#   'brutal',
#   'guerrilla',
#   'terrorist',
#   'bane'],
#  ['journey',
#   'find',
#   'cure',
#   'tatarigami',
#   'curse',
#   'ashitaka',
#   'finds',
#   'middle',
#   'war',
#   'forest',
#   'gods',
#   'tatara',
#   'mining',
#   'colony',
#   'quest',
#   'also',
#   'meets',
#   'san',
#   'mononoke',
#   'hime'],
#  ['moon',
#   'alien',
#   'colonized',
#   'contact',
#   'lost',
#   'time',
#   'rescue',
#   'team',
#   'impressive',
#   'firepower',
#   'enough'],
#  ['kidnapped',
#   'imprisoned',
#   'fifteen',
#   'years',
#   'dae',
#   'released',
#   'find',
#   'must',
#   'find',
#   'captor',
#   'five',
#   'days'],
#  ['former',
#   'prohibition',
#   'era',
#   'jewish',
#   'gangster',
#   'returns',
#   'lower',
#   'east',
#   'side',
#   'manhattan',
#   'thirty',
#   'years',
#   'later',
#   'must',
#   'confront',
#   'ghosts',
#   'regrets',
#   'old',
#   'life'],
#  ['veteran',
#   'british',
#   'barrister',
#   'must',
#   'defend',
#   'client',
#   'murder',
#   'trial',
#   'surprise',
#   'surprise'],
#  ['claustrophobic',
#   'world',
#   'wwii',
#   'german',
#   'boat',
#   'boredom',
#   'filth',
#   'sheer',
#   'terror'],
#  ['following',
#   'death',
#   'publishing',
#   'tycoon',
#   'news',
#   'reporters',
#   'scramble',
#   'discover',
#   'meaning',
#   'final',
#   'utterance'],
#  ['former',
#   'wrestler',
#   'mahavir',
#   'singh',
#   'phogat',
#   'two',
#   'wrestler',
#   'daughters',
#   'struggle',
#   'towards',
#   'glory',
#   'commonwealth',
#   'games',
#   'face',
#   'societal',
#   'oppression'],
#  ['hapless',
#   'new',
#   'york',
#   'advertising',
#   'executive',
#   'mistaken',
#   'government',
#   'agent',
#   'group',
#   'foreign',
#   'spies',
#   'pursued',
#   'across',
#   'country',
#   'looks',
#   'way',
#   'survive'],
#  ['san',
#   'francisco',
#   'detective',
#   'suffering',
#   'acrophobia',
#   'investigates',
#   'strange',
#   'activities',
#   'old',
#   'friend',
#   'wife',
#   'becoming',
#   'dangerously',
#   'obsessed'],
#  ['daring',
#   'mission',
#   'rescue',
#   'han',
#   'solo',
#   'jabba',
#   'hutt',
#   'rebels',
#   'dispatch',
#   'endor',
#   'destroy',
#   'powerful',
#   'death',
#   'star',
#   'meanwhile',
#   'luke',
#   'struggles',
#   'help',
#   'vader',
#   'back',
#   'dark',
#   'side',
#   'without',
#   'falling',
#   'emperor',
#   'trap'],
#  ['simple',
#   'jewelry',
#   'heist',
#   'goes',
#   'terribly',
#   'wrong',
#   'surviving',
#   'criminals',
#   'begin',
#   'suspect',
#   'one',
#   'police',
#   'informant'],
#  ['secret',
#   'bride',
#   'executed',
#   'assaulting',
#   'english',
#   'soldier',
#   'tried',
#   'rape',
#   'sir',
#   'william',
#   'wallace',
#   'begins',
#   'revolt',
#   'king',
#   'edward',
#   'england'],
#  ['police',
#   'german',
#   'city',
#   'unable',
#   'catch',
#   'child',
#   'murderer',
#   'criminals',
#   'join',
#   'manhunt'],
#  ['drug',
#   'induced',
#   'utopias',
#   'four',
#   'coney',
#   'island',
#   'people',
#   'shattered',
#   'addictions',
#   'run',
#   'deep'],
#  ['lie',
#   'innocent',
#   'naive',
#   'girl',
#   'paris',
#   'sense',
#   'justice',
#   'decides',
#   'help',
#   'around',
#   'along',
#   'way',
#   'discovers',
#   'love'],
#  ['eight',
#   'year',
#   'old',
#   'boy',
#   'thought',
#   'lazy',
#   'trouble',
#   'maker',
#   'new',
#   'art',
#   'teacher',
#   'patience',
#   'compassion',
#   'discover',
#   'real',
#   'problem',
#   'behind',
#   'struggles',
#   'school'],
#  ['future',
#   'britain',
#   'alex',
#   'delarge',
#   'charismatic',
#   'psycopath',
#   'delinquent',
#   'likes',
#   'practice',
#   'crimes',
#   'ultra',
#   'violence',
#   'gang',
#   'jailed',
#   'volunteers',
#   'experimental',
#   'aversion',
#   'therapy',
#   'developed',
#   'government',
#   'effort',
#   'solve',
#   'society',
#   'crime',
#   'problem',
#   'goes',
#   'according',
#   'plan'],
#  ['story',
#   'lawrence',
#   'english',
#   'officer',
#   'successfully',
#   'united',
#   'led',
#   'diverse',
#   'often',
#   'warring',
#   'arab',
#   'tribes',
#   'world',
#   'war',
#   'order',
#   'fight',
#   'turks'],
#  ['mentally',
#   'unstable',
#   'vietnam',
#   'war',
#   'veteran',
#   'works',
#   'night',
#   'time',
#   'taxi',
#   'driver',
#   'new',
#   'york',
#   'city',
#   'perceived',
#   'decadence',
#   'sleaze',
#   'feeds',
#   'urge',
#   'violent',
#   'action',
#   'attempting',
#   'save',
#   'preadolescent',
#   'prostitute',
#   'process'],
#  ['insurance',
#   'representative',
#   'lets',
#   'talked',
#   'murder',
#   'insurance',
#   'fraud',
#   'scheme',
#   'arouses',
#   'insurance',
#   'investigator',
#   'suspicions'],
#  ['relationship',
#   'turns',
#   'sour',
#   'couple',
#   'undergoes',
#   'procedure',
#   'erased',
#   'memories',
#   'process',
#   'loss',
#   'discover',
#   'begin'],
#  ['incredible',
#   'story',
#   'wolfgang',
#   'amadeus',
#   'mozart',
#   'told',
#   'peer',
#   'secret',
#   'rival',
#   'antonio',
#   'salieri',
#   'confined',
#   'insane',
#   'asylum'],
#  ['atticus',
#   'finch',
#   'lawyer',
#   'depression',
#   'era',
#   'south',
#   'defends',
#   'black',
#   'man',
#   'undeserved',
#   'rape',
#   'charge',
#   'children',
#   'prejudice'],
#  ['toys',
#   'mistakenly',
#   'delivered',
#   'day',
#   'care',
#   'center',
#   'instead',
#   'attic',
#   'right',
#   'andy',
#   'leaves',
#   'college',
#   'woody',
#   'convince',
#   'toys',
#   'abandoned',
#   'return',
#   'home'],
#  ['pragmatic',
#   'marine',
#   'observes',
#   'dehumanizing',
#   'effects',
#   'vietnam',
#   'war',
#   'fellow',
#   'recruits',
#   'brutal',
#   'boot',
#   'camp',
#   'training',
#   'bloody',
#   'street',
#   'fighting',
#   'hue'],
#  ['humanity',
#   'finds',
#   'mysterious',
#   'obviously',
#   'artificial',
#   'object',
#   'buried',
#   'beneath',
#   'lunar',
#   'surface',
#   'intelligent',
#   'computer',
#   'sets',
#   'quest'],
#  ['silent',
#   'film',
#   'production',
#   'company',
#   'cast',
#   'make',
#   'difficult',
#   'transition',
#   'sound'],
#  ['two',
#   'strangers',
#   'find',
#   'linked',
#   'bizarre',
#   'way',
#   'connection',
#   'forms',
#   'distance',
#   'thing',
#   'keep',
#   'apart'],
#  ['chicago',
#   'september',
#   'young',
#   'con',
#   'man',
#   'seeking',
#   'revenge',
#   'murdered',
#   'partner',
#   'teams',
#   'master',
#   'big',
#   'con',
#   'win',
#   'fortune',
#   'criminal',
#   'banker'],
#  ['cowboy',
#   'doll',
#   'profoundly',
#   'threatened',
#   'jealous',
#   'new',
#   'spaceman',
#   'figure',
#   'supplants',
#   'top',
#   'toy',
#   'boy',
#   'room'],
#  ['post',
#   'war',
#   'italy',
#   'working',
#   'class',
#   'man',
#   'bicycle',
#   'stolen',
#   'son',
#   'set',
#   'find'],
#  ['tramp',
#   'cares',
#   'abandoned',
#   'child',
#   'events',
#   'put',
#   'relationship',
#   'jeopardy'],
#  ['nazi',
#   'occupied',
#   'france',
#   'world',
#   'war',
#   'plan',
#   'assassinate',
#   'nazi',
#   'leaders',
#   'group',
#   'jewish',
#   'soldiers',
#   'coincides',
#   'theatre',
#   'owner',
#   'vengeful',
#   'plans'],
#  ['two',
#   'friends',
#   'searching',
#   'long',
#   'lost',
#   'companion',
#   'revisit',
#   'college',
#   'days',
#   'recall',
#   'memories',
#   'friend',
#   'inspired',
#   'think',
#   'differently',
#   'even',
#   'rest',
#   'world',
#   'called',
#   'idiots'],
#  ['unscrupulous',
#   'boxing',
#   'promoters',
#   'violent',
#   'bookmakers',
#   'russian',
#   'gangster',
#   'incompetent',
#   'amateur',
#   'robbers',
#   'supposedly',
#   'jewish',
#   'jewelers',
#   'fight',
#   'track',
#   'priceless',
#   'stolen',
#   'diamond'],
#  ['king',
#   'arthur',
#   'knights',
#   'embark',
#   'low',
#   'budget',
#   'search',
#   'grail',
#   'encountering',
#   'many',
#   'silly',
#   'obstacles'],
#  ['corruption',
#   'grows',
#   'three',
#   'policemen',
#   'one',
#   'strait',
#   'laced',
#   'one',
#   'brutal',
#   'one',
#   'sleazy',
#   'investigate',
#   'series',
#   'murders',
#   'brand',
#   'justice'],
#  ['two',
#   'bounty',
#   'hunters',
#   'intentions',
#   'team',
#   'track',
#   'western',
#   'outlaw'],
#  ['teacher',
#   'lives',
#   'lonely',
#   'life',
#   'struggling',
#   'son',
#   'custody',
#   'life',
#   'slowly',
#   'gets',
#   'better',
#   'finds',
#   'love',
#   'receives',
#   'good',
#   'news',
#   'son',
#   'new',
#   'luck',
#   'brutally',
#   'shattered',
#   'innocent',
#   'little',
#   'lie'],
#  ['hunting',
#   'janitor',
#   'gift',
#   'mathematics',
#   'needs',
#   'help',
#   'psychologist',
#   'find',
#   'direction',
#   'life'],
#  ['miami',
#   'determined',
#   'cuban',
#   'immigrant',
#   'takes',
#   'drug',
#   'cartel',
#   'succumbs',
#   'greed'],
#  ['family',
#   'left',
#   'wing',
#   'journalist',
#   'torn',
#   'apart',
#   'military',
#   'coup',
#   'turkey'],
#  ['man',
#   'tries',
#   'rise',
#   'company',
#   'letting',
#   'executives',
#   'use',
#   'apartment',
#   'trysts',
#   'complications',
#   'romance',
#   'ensue'],
#  ['heinous', 'crime', 'aftermath', 'recalled', 'differing', 'points', 'view'],
#  ['married',
#   'couple',
#   'faced',
#   'difficult',
#   'decision',
#   'improve',
#   'life',
#   'child',
#   'moving',
#   'another',
#   'country',
#   'stay',
#   'iran',
#   'look',
#   'deteriorating',
#   'parent',
#   'alzheimer',
#   'disease'],
#  ['futuristic',
#   'city',
#   'sharply',
#   'divided',
#   'working',
#   'class',
#   'city',
#   'planners',
#   'son',
#   'city',
#   'mastermind',
#   'falls',
#   'love',
#   'working',
#   'class',
#   'prophet',
#   'predicts',
#   'coming',
#   'savior',
#   'mediate',
#   'differences'],
#  ['henry',
#   'jones',
#   'suddenly',
#   'goes',
#   'missing',
#   'pursuing',
#   'holy',
#   'grail',
#   'eminent',
#   'archaeologist',
#   'indiana',
#   'jones',
#   'must',
#   'follow',
#   'father',
#   'footsteps',
#   'stop',
#   'nazis',
#   'getting',
#   'hands',
#   'holy',
#   'grail',
#   'first'],
#  ['ingenue',
#   'insinuates',
#   'company',
#   'established',
#   'aging',
#   'stage',
#   'actress',
#   'circle',
#   'theater',
#   'friends'],
#  ['crafty',
#   'ronin',
#   'comes',
#   'town',
#   'divided',
#   'two',
#   'criminal',
#   'gangs',
#   'decides',
#   'play',
#   'free',
#   'town'],
#  ['training',
#   'mentor',
#   'batman',
#   'begins',
#   'fight',
#   'free',
#   'crime',
#   'ridden',
#   'gotham',
#   'city',
#   'corruption',
#   'scarecrow',
#   'league',
#   'shadows',
#   'cast',
#   'upon'],
#  ['seventy',
#   'eight',
#   'year',
#   'old',
#   'carl',
#   'fredricksen',
#   'travels',
#   'paradise',
#   'falls',
#   'home',
#   'equipped',
#   'balloons',
#   'inadvertently',
#   'taking',
#   'young',
#   'stowaway'],
#  ['two',
#   'male',
#   'musicians',
#   'witness',
#   'mob',
#   'hit',
#   'flee',
#   'state',
#   'female',
#   'band',
#   'disguised',
#   'women',
#   'complications',
#   'set'],
#  ['fred',
#   'dobbs',
#   'bob',
#   'curtin',
#   'two',
#   'americans',
#   'searching',
#   'work',
#   'mexico',
#   'convince',
#   'old',
#   'prospector',
#   'help',
#   'mine',
#   'gold',
#   'sierra',
#   'madre',
#   'mountains'],
#  ['retired',
#   'old',
#   'west',
#   'gunslinger',
#   'william',
#   'munny',
#   'reluctantly',
#   'takes',
#   'one',
#   'last',
#   'job',
#   'help',
#   'old',
#   'partner',
#   'young',
#   'man'],
#  ['traudl',
#   'junge',
#   'final',
#   'secretary',
#   'adolf',
#   'hitler',
#   'tells',
#   'nazi',
#   'dictator',
#   'final',
#   'days',
#   'berlin',
#   'bunker',
#   'end',
#   'wwii'],
#  ['emotionally',
#   'self',
#   'destructive',
#   'boxer',
#   'journey',
#   'life',
#   'violence',
#   'temper',
#   'leads',
#   'top',
#   'ring',
#   'destroys',
#   'life',
#   'outside'],
#  ['john',
#   'mcclane',
#   'officer',
#   'nypd',
#   'tries',
#   'save',
#   'wife',
#   'holly',
#   'gennaro',
#   'several',
#   'others',
#   'taken',
#   'hostage',
#   'german',
#   'terrorist',
#   'hans',
#   'gruber',
#   'christmas',
#   'party',
#   'nakatomi',
#   'plaza',
#   'los',
#   'angeles'],
#  ['pulp',
#   'novelist',
#   'holly',
#   'martins',
#   'travels',
#   'shadowy',
#   'postwar',
#   'vienna',
#   'find',
#   'investigating',
#   'mysterious',
#   'death',
#   'old',
#   'friend',
#   'harry',
#   'lime'],
#  ['boy',
#   'loses',
#   'sister',
#   'pair',
#   'shoes',
#   'goes',
#   'series',
#   'adventures',
#   'order',
#   'find',
#   'tries',
#   'new',
#   'way',
#   'win',
#   'new',
#   'pair'],
#  ['group',
#   'professional',
#   'bank',
#   'robbers',
#   'start',
#   'feel',
#   'heat',
#   'police',
#   'unknowingly',
#   'leave',
#   'clue',
#   'latest',
#   'heist',
#   'sides',
#   'attempt',
#   'find',
#   'balance',
#   'personal',
#   'lives',
#   'professional',
#   'lives'],
#  ['allied',
#   'prisoners',
#   'war',
#   'plan',
#   'several',
#   'hundred',
#   'number',
#   'escape',
#   'german',
#   'camp',
#   'world',
#   'war'],
#  ['private',
#   'detective',
#   'hired',
#   'expose',
#   'adulterer',
#   'finds',
#   'caught',
#   'web',
#   'deceit',
#   'corruption',
#   'murder'],
#  ['bureaucrat',
#   'tries',
#   'find',
#   'meaning',
#   'life',
#   'discovers',
#   'terminal',
#   'cancer'],
#  ['falangist',
#   'spain',
#   'bookish',
#   'young',
#   'stepdaughter',
#   'sadistic',
#   'army',
#   'officer',
#   'escapes',
#   'eerie',
#   'captivating',
#   'fantasy',
#   'world'],
#  ['two',
#   'girls',
#   'move',
#   'country',
#   'near',
#   'ailing',
#   'mother',
#   'adventures',
#   'wondrous',
#   'forest',
#   'spirits',
#   'live',
#   'nearby'],
#  ['coerced',
#   'working',
#   'crime',
#   'boss',
#   'young',
#   'getaway',
#   'driver',
#   'finds',
#   'taking',
#   'part',
#   'heist',
#   'doomed',
#   'fail'],
#  ['young',
#   'riley',
#   'uprooted',
#   'midwest',
#   'life',
#   'moved',
#   'san',
#   'francisco',
#   'emotions',
#   'joy',
#   'fear',
#   'anger',
#   'disgust',
#   'sadness',
#   'conflict',
#   'best',
#   'navigate',
#   'new',
#   'city',
#   'house',
#   'school'],
#  ['medieval',
#   'japan',
#   'elderly',
#   'warlord',
#   'retires',
#   'handing',
#   'empire',
#   'three',
#   'sons',
#   'however',
#   'vastly',
#   'underestimates',
#   'new',
#   'found',
#   'power',
#   'corrupt',
#   'cause',
#   'turn'],
#  ['prospector', 'goes', 'klondike', 'search', 'gold', 'finds'],
#  ['prize',
#   'fighter',
#   'turned',
#   'longshoreman',
#   'struggles',
#   'stand',
#   'corrupt',
#   'union',
#   'bosses'],
#  ['retired',
#   'legal',
#   'counselor',
#   'writes',
#   'novel',
#   'hoping',
#   'find',
#   'closure',
#   'one',
#   'past',
#   'unresolved',
#   'homicide',
#   'cases',
#   'unreciprocated',
#   'love',
#   'superior',
#   'still',
#   'haunt',
#   'decades',
#   'later'],
#  ['young', 'boy', 'raised', 'within', 'confines', 'small', 'shed'],
#  ['settling',
#   'differences',
#   'japanese',
#   'pow',
#   'camp',
#   'commander',
#   'british',
#   'colonel',
#   'operates',
#   'oversee',
#   'men',
#   'construction',
#   'railway',
#   'bridge',
#   'captors',
#   'oblivious',
#   'plan',
#   'allies',
#   'destroy'],
#  ['blade',
#   'runner',
#   'must',
#   'pursue',
#   'try',
#   'terminate',
#   'four',
#   'replicants',
#   'stole',
#   'ship',
#   'space',
#   'returned',
#   'earth',
#   'find',
#   'creator'],
#  ['unconfident',
#   'young',
#   'woman',
#   'cursed',
#   'old',
#   'body',
#   'spiteful',
#   'witch',
#   'chance',
#   'breaking',
#   'spell',
#   'lies',
#   'self',
#   'indulgent',
#   'yet',
#   'insecure',
#   'young',
#   'wizard',
#   'companions',
#   'legged',
#   'walking',
#   'castle'],
#  ['jazz', 'pianist', 'falls', 'aspiring', 'actress', 'los', 'angeles'],
#  ['twins',
#   'journey',
#   'middle',
#   'east',
#   'discover',
#   'family',
#   'history',
#   'fulfill',
#   'mother',
#   'last',
#   'wishes'],
#  ['american',
#   'court',
#   'occupied',
#   'germany',
#   'tries',
#   'four',
#   'nazi',
#   'judges',
#   'war',
#   'crimes'],
#  ['man',
#   'seeks',
#   'answers',
#   'life',
#   'death',
#   'existence',
#   'god',
#   'plays',
#   'chess',
#   'grim',
#   'reaper',
#   'black',
#   'plague'],
#  ['botched',
#   'card',
#   'game',
#   'london',
#   'triggers',
#   'four',
#   'friends',
#   'thugs',
#   'weed',
#   'growers',
#   'hard',
#   'gangsters',
#   'loan',
#   'sharks',
#   'debt',
#   'collectors',
#   'collide',
#   'series',
#   'unexpected',
#   'events',
#   'sake',
#   'weed',
#   'cash',
#   'two',
#   'antique',
#   'shotguns'],
#  ['naive',
#   'man',
#   'appointed',
#   'fill',
#   'vacancy',
#   'united',
#   'states',
#   'senate',
#   'plans',
#   'promptly',
#   'collide',
#   'political',
#   'corruption',
#   'back'],
#  ['greed',
#   'deception',
#   'money',
#   'power',
#   'murder',
#   'occur',
#   'two',
#   'best',
#   'friends',
#   'mafia',
#   'underboss',
#   'casino',
#   'owner',
#   'trophy',
#   'wife',
#   'gambling',
#   'empire'],
#  ['john',
#   'nash',
#   'brilliant',
#   'asocial',
#   'mathematician',
#   'accepts',
#   'secret',
#   'work',
#   'cryptography',
#   'life',
#   'takes',
#   'turn',
#   'nightmarish'],
#  ['near',
#   'future',
#   'weary',
#   'logan',
#   'cares',
#   'ailing',
#   'professor',
#   'somewhere',
#   'mexican',
#   'border',
#   'however',
#   'logan',
#   'attempts',
#   'hide',
#   'world',
#   'legacy',
#   'upended',
#   'young',
#   'mutant',
#   'arrives',
#   'pursued',
#   'dark',
#   'forces'],
#  ['victorian',
#   'surgeon',
#   'rescues',
#   'heavily',
#   'disfigured',
#   'man',
#   'mistreated',
#   'scraping',
#   'living',
#   'side',
#   'show',
#   'freak',
#   'behind',
#   'monstrous',
#   'facade',
#   'revealed',
#   'person',
#   'intelligence',
#   'sensitivity'],
#  ['life',
#   'times',
#   'afflictions',
#   'fifteenth',
#   'century',
#   'russian',
#   'iconographer'],
#  ['living',
#   'life',
#   'marked',
#   'coldness',
#   'aging',
#   'professor',
#   'forced',
#   'confront',
#   'emptiness',
#   'existence'],
#  ['future',
#   'british',
#   'tyranny',
#   'shadowy',
#   'freedom',
#   'fighter',
#   'known',
#   'alias',
#   'plots',
#   'overthrow',
#   'help',
#   'young',
#   'woman'],
#  ['union',
#   'spies',
#   'steal',
#   'engineer',
#   'beloved',
#   'locomotive',
#   'pursues',
#   'single',
#   'handedly',
#   'straight',
#   'enemy',
#   'lines'],
#  ['based',
#   'true',
#   'story',
#   'jordan',
#   'belfort',
#   'rise',
#   'wealthy',
#   'stock',
#   'broker',
#   'living',
#   'high',
#   'life',
#   'fall',
#   'involving',
#   'crime',
#   'corruption',
#   'federal',
#   'government'],
#  ['youngest',
#   'son',
#   'alcoholic',
#   'former',
#   'boxer',
#   'returns',
#   'home',
#   'trained',
#   'father',
#   'competition',
#   'mixed',
#   'martial',
#   'arts',
#   'tournament',
#   'path',
#   'puts',
#   'fighter',
#   'collision',
#   'course',
#   'estranged',
#   'older',
#   'brother'],
#  ['epic',
#   'adventures',
#   'legendary',
#   'baran',
#   'bandit',
#   'following',
#   'release',
#   'prison',
#   'serving',
#   'years',
#   'surprise',
#   'world',
#   'changed',
#   'dramatically',
#   'still',
#   'baran'],
#  ['renton',
#   'deeply',
#   'immersed',
#   'edinburgh',
#   'drug',
#   'scene',
#   'tries',
#   'clean',
#   'get',
#   'despite',
#   'allure',
#   'drugs',
#   'influence',
#   'friends'],
#  ['allegorical',
#   'tale',
#   'man',
#   'fighting',
#   'good',
#   'evil',
#   'within',
#   'sides',
#   'made',
#   'flesh',
#   'one',
#   'sophisticated',
#   'woman',
#   'attracted',
#   'wife'],
#  ['tennis',
#   'pro',
#   'carries',
#   'plot',
#   'murder',
#   'wife',
#   'things',
#   'wrong',
#   'improvises',
#   'brilliant',
#   'plan'],
#  ['disgruntled',
#   'korean',
#   'war',
#   'veteran',
#   'walt',
#   'kowalski',
#   'sets',
#   'reform',
#   'neighbor',
#   'hmong',
#   'teenager',
#   'tried',
#   'steal',
#   'kowalski',
#   'prized',
#   'possession',
#   'gran',
#   'torino'],
#  ['depth',
#   'examination',
#   'ways',
#   'vietnam',
#   'war',
#   'impacts',
#   'disrupts',
#   'lives',
#   'people',
#   'small',
#   'industrial',
#   'town',
#   'pennsylvania'],
#  ['wwii',
#   'american',
#   'army',
#   'medic',
#   'desmond',
#   'doss',
#   'served',
#   'battle',
#   'okinawa',
#   'refuses',
#   'kill',
#   'people',
#   'becomes',
#   'first',
#   'man',
#   'american',
#   'history',
#   'receive',
#   'medal',
#   'honor',
#   'without',
#   'firing',
#   'shot'],
#  ['manipulative',
#   'woman',
#   'roguish',
#   'man',
#   'conduct',
#   'turbulent',
#   'romance',
#   'american',
#   'civil',
#   'war',
#   'reconstruction',
#   'periods'],
#  ['jerry',
#   'lundegaard',
#   'inept',
#   'crime',
#   'falls',
#   'apart',
#   'due',
#   'henchmen',
#   'bungling',
#   'persistent',
#   'police',
#   'work',
#   'quite',
#   'pregnant',
#   'marge',
#   'gunderson'],
#  ['dude',
#   'lebowski',
#   'mistaken',
#   'millionaire',
#   'lebowski',
#   'seeks',
#   'restitution',
#   'ruined',
#   'rug',
#   'enlists',
#   'bowling',
#   'buddies',
#   'help',
#   'get'],
#  ['boy',
#   'communicates',
#   'spirits',
#   'know',
#   'dead',
#   'seeks',
#   'help',
#   'disheartened',
#   'child',
#   'psychologist'],
#  ['research',
#   'facility',
#   'antarctica',
#   'comes',
#   'across',
#   'alien',
#   'force',
#   'become',
#   'anything',
#   'touches',
#   'accuracy',
#   'members',
#   'must',
#   'find',
#   'human',
#   'late'],
#  ['son',
#   'captured',
#   'great',
#   'barrier',
#   'reef',
#   'taken',
#   'sydney',
#   'timid',
#   'clownfish',
#   'sets',
#   'journey',
#   'bring',
#   'home'],
#  ['old',
#   'couple',
#   'visit',
#   'children',
#   'grandchildren',
#   'city',
#   'children',
#   'little',
#   'time'],
#  ['violence',
#   'mayhem',
#   'ensue',
#   'hunter',
#   'stumbles',
#   'upon',
#   'drug',
#   'deal',
#   'gone',
#   'wrong',
#   'two',
#   'million',
#   'dollars',
#   'cash',
#   'near',
#   'rio',
#   'grande'],
#  ['story',
#   'six',
#   'friends',
#   'help',
#   'english',
#   'filmmaker',
#   'create',
#   'documentary',
#   'indian',
#   'freedom',
#   'struggle',
#   'filming',
#   'group',
#   'friends',
#   'learn',
#   'importance',
#   'fighting',
#   'rights'],
#  ['chronicle',
#   'trial',
#   'jeanne',
#   'arc',
#   'charges',
#   'heresy',
#   'efforts',
#   'ecclesiastical',
#   'jurists',
#   'force',
#   'jeanne',
#   'recant',
#   'claims',
#   'holy',
#   'visions'],
#  ['man', 'refuses', 'conform', 'life', 'rural', 'prison'],
#  ['self',
#   'conscious',
#   'bride',
#   'tormented',
#   'memory',
#   'husband',
#   'dead',
#   'first',
#   'wife'],
#  ['retiring',
#   'police',
#   'officer',
#   'reminisces',
#   'astounding',
#   'day',
#   'career',
#   'case',
#   'never',
#   'filed',
#   'continues',
#   'haunt',
#   'memories',
#   'case',
#   'man',
#   'wednesday'],
#  ['story',
#   'family',
#   'religion',
#   'hatred',
#   'oil',
#   'madness',
#   'focusing',
#   'turn',
#   'century',
#   'prospector',
#   'early',
#   'days',
#   'business'],
#  ['hapless',
#   'young',
#   'viking',
#   'aspires',
#   'hunt',
#   'dragons',
#   'becomes',
#   'unlikely',
#   'friend',
#   'young',
#   'dragon',
#   'learns',
#   'may',
#   'creatures',
#   'assumed'],
#  ['bride',
#   'wakens',
#   'four',
#   'year',
#   'coma',
#   'child',
#   'carried',
#   'womb',
#   'gone',
#   'must',
#   'wreak',
#   'vengeance',
#   'team',
#   'assassins',
#   'betrayed',
#   'team',
#   'part'],
#  ['finding',
#   'old',
#   'rifle',
#   'young',
#   'boy',
#   'joins',
#   'soviet',
#   'resistance',
#   'movement',
#   'ruthless',
#   'german',
#   'forces',
#   'experiences',
#   'horrors',
#   'world',
#   'war'],
#  ['tale',
#   'friendship',
#   'two',
#   'unlikely',
#   'pen',
#   'pals',
#   'mary',
#   'lonely',
#   'eight',
#   'year',
#   'old',
#   'girl',
#   'living',
#   'suburbs',
#   'melbourne',
#   'max',
#   'forty',
#   'four',
#   'year',
#   'old',
#   'severely',
#   'obese',
#   'man',
#   'living',
#   'new',
#   'york'],
#  ['wife',
#   'disappearance',
#   'become',
#   'focus',
#   'intense',
#   'media',
#   'circus',
#   'man',
#   'sees',
#   'spotlight',
#   'turned',
#   'suspected',
#   'may',
#   'innocent'],
#  ['graduating',
#   'emory',
#   'university',
#   'top',
#   'student',
#   'athlete',
#   'christopher',
#   'mccandless',
#   'abandons',
#   'possessions',
#   'gives',
#   'entire',
#   'savings',
#   'account',
#   'charity',
#   'hitchhikes',
#   'alaska',
#   'live',
#   'wilderness',
#   'along',
#   'way',
#   'christopher',
#   'encounters',
#   'series',
#   'characters',
#   'shape',
#   'life'],
#  ['spoiled',
#   'heiress',
#   'running',
#   'away',
#   'family',
#   'helped',
#   'man',
#   'actually',
#   'reporter',
#   'need',
#   'story'],
#  ['marshal',
#   'investigates',
#   'disappearance',
#   'murderess',
#   'escaped',
#   'hospital',
#   'criminally',
#   'insane'],
#  ['brian',
#   'born',
#   'original',
#   'christmas',
#   'stable',
#   'next',
#   'door',
#   'spends',
#   'life',
#   'mistaken',
#   'messiah'],
#  ['young',
#   'recruit',
#   'vietnam',
#   'faces',
#   'moral',
#   'crisis',
#   'confronted',
#   'horrors',
#   'war',
#   'duality',
#   'man'],
#  ['six',
#   'short',
#   'stories',
#   'explore',
#   'extremities',
#   'human',
#   'behavior',
#   'involving',
#   'people',
#   'distress'],
#  ['paul',
#   'rusesabagina',
#   'hotel',
#   'manager',
#   'housed',
#   'thousand',
#   'tutsi',
#   'refugees',
#   'struggle',
#   'hutu',
#   'militia',
#   'rwanda'],
#  ['merciless',
#   'rivalry',
#   'formula',
#   'one',
#   'rivals',
#   'james',
#   'hunt',
#   'niki',
#   'lauda'],
#  ['decrepit',
#   'south',
#   'american',
#   'village',
#   'four',
#   'men',
#   'hired',
#   'transport',
#   'urgent',
#   'nitroglycerine',
#   'shipment',
#   'without',
#   'equipment',
#   'would',
#   'make',
#   'safe'],
#  ['television',
#   'network',
#   'cynically',
#   'exploits',
#   'deranged',
#   'former',
#   'anchor',
#   'ravings',
#   'revelations',
#   'news',
#   'media',
#   'profit'],
#  ['man',
#   'coerced',
#   'confession',
#   'ira',
#   'bombing',
#   'commit',
#   'results',
#   'imprisonment',
#   'father',
#   'well',
#   'english',
#   'lawyer',
#   'fights',
#   'free'],
#  ['death',
#   'friend',
#   'writer',
#   'recounts',
#   'boyhood',
#   'journey',
#   'find',
#   'body',
#   'missing',
#   'boy'],
#  ['moving',
#   'story',
#   'young',
#   'boy',
#   'left',
#   'without',
#   'attention',
#   'delves',
#   'life',
#   'petty',
#   'crime'],
#  ['jewish',
#   'prince',
#   'betrayed',
#   'sent',
#   'slavery',
#   'roman',
#   'friend',
#   'regains',
#   'freedom',
#   'comes',
#   'back',
#   'revenge'],
#  ['adventures',
#   'gustave',
#   'legendary',
#   'concierge',
#   'famous',
#   'hotel',
#   'fictional',
#   'republic',
#   'zubrowka',
#   'first',
#   'second',
#   'world',
#   'wars',
#   'zero',
#   'moustafa',
#   'lobby',
#   'boy',
#   'becomes',
#   'trusted',
#   'friend'],
#  ['true',
#   'story',
#   'boston',
#   'globe',
#   'uncovered',
#   'massive',
#   'scandal',
#   'child',
#   'molestation',
#   'cover',
#   'within',
#   'local',
#   'catholic',
#   'archdiocese',
#   'shaking',
#   'entire',
#   'catholic',
#   'church',
#   'core'],
#  ['woman',
#   'rebels',
#   'tyrannical',
#   'ruler',
#   'postapocalyptic',
#   'australia',
#   'search',
#   'home',
#   'land',
#   'help',
#   'group',
#   'female',
#   'prisoners',
#   'psychotic',
#   'worshipper',
#   'drifter',
#   'named',
#   'max'],
#  ['antebellum',
#   'united',
#   'states',
#   'solomon',
#   'northup',
#   'free',
#   'black',
#   'man',
#   'upstate',
#   'new',
#   'york',
#   'abducted',
#   'sold',
#   'slavery'],
#  ['nurse',
#   'put',
#   'charge',
#   'mute',
#   'actress',
#   'finds',
#   'personas',
#   'melding',
#   'together'],
#  ['determined',
#   'woman',
#   'works',
#   'hardened',
#   'boxing',
#   'trainer',
#   'become',
#   'professional'],
#  ['two',
#   'western',
#   'bank',
#   'train',
#   'robbers',
#   'flee',
#   'bolivia',
#   'law',
#   'gets',
#   'close'],
#  ['preview',
#   'tour',
#   'theme',
#   'park',
#   'suffers',
#   'major',
#   'power',
#   'breakdown',
#   'allows',
#   'cloned',
#   'dinosaur',
#   'exhibits',
#   'run',
#   'amok'],
#  ['small',
#   'korean',
#   'province',
#   'three',
#   'detectives',
#   'struggle',
#   'case',
#   'multiple',
#   'young',
#   'women',
#   'found',
#   'raped',
#   'murdered',
#   'unknown',
#   'culprit'],
#  ['horrific',
#   'car',
#   'accident',
#   'connects',
#   'three',
#   'stories',
#   'involving',
#   'characters',
#   'dealing',
#   'loss',
#   'regret',
#   'life',
#   'harsh',
#   'realities',
#   'name',
#   'love'],
#  ['private',
#   'detective',
#   'takes',
#   'case',
#   'involves',
#   'three',
#   'eccentric',
#   'criminals',
#   'gorgeous',
#   'liar',
#   'quest',
#   'priceless',
#   'statuette'],
#  ['gangster', 'sets', 'fulfill', 'father', 'dream', 'becoming', 'doctor'],
#  ['guide',
#   'leads',
#   'two',
#   'men',
#   'area',
#   'known',
#   'zone',
#   'find',
#   'room',
#   'grants',
#   'wishes'],
#  ['insurance',
#   'salesman',
#   'adjuster',
#   'discovers',
#   'entire',
#   'life',
#   'actually',
#   'television',
#   'show'],
#  ['waifish',
#   'prostitute',
#   'wanders',
#   'streets',
#   'rome',
#   'looking',
#   'true',
#   'love',
#   'finds',
#   'heartbreak'],
#  ['home',
#   'sick',
#   'bed',
#   'young',
#   'boy',
#   'grandfather',
#   'reads',
#   'story',
#   'called',
#   'princess',
#   'bride'],
#  ['college', 'professor', 'bond', 'abandoned', 'dog', 'takes', 'home'],
#  ['warrior',
#   'pacifist',
#   'princess',
#   'nausica',
#   'desperately',
#   'struggles',
#   'prevent',
#   'two',
#   'warring',
#   'nations',
#   'destroying',
#   'dying',
#   'planet'],
#  ['young',
#   'man',
#   'woman',
#   'meet',
#   'train',
#   'europe',
#   'wind',
#   'spending',
#   'one',
#   'evening',
#   'together',
#   'vienna',
#   'unfortunately',
#   'know',
#   'probably',
#   'night',
#   'together'],
#  ['three',
#   'decades',
#   'empire',
#   'defeat',
#   'new',
#   'threat',
#   'arises',
#   'militant',
#   'first',
#   'order',
#   'stormtrooper',
#   'defector',
#   'finn',
#   'spare',
#   'parts',
#   'scavenger',
#   'rey',
#   'caught',
#   'resistance',
#   'search',
#   'missing',
#   'luke',
#   'skywalker'],
#  ['family',
#   'murdered',
#   'notorious',
#   'ruthless',
#   'bandit',
#   'former',
#   'police',
#   'officer',
#   'enlists',
#   'services',
#   'two',
#   'outlaws',
#   'capture',
#   'bandit'],
#  ['poor',
#   'midwest',
#   'family',
#   'forced',
#   'land',
#   'travel',
#   'california',
#   'suffering',
#   'misfortunes',
#   'homeless',
#   'great',
#   'depression'],
#  ['harry',
#   'ron',
#   'hermione',
#   'search',
#   'voldemort',
#   'remaining',
#   'horcruxes',
#   'effort',
#   'destroy',
#   'dark',
#   'lord',
#   'final',
#   'battle',
#   'rages',
#   'hogwarts'],
#  ['rocky',
#   'balboa',
#   'small',
#   'time',
#   'boxer',
#   'gets',
#   'supremely',
#   'rare',
#   'chance',
#   'fight',
#   'heavy',
#   'weight',
#   'champion',
#   'apollo',
#   'creed',
#   'bout',
#   'strives',
#   'distance',
#   'self',
#   'respect'],
#  ['keller',
#   'dover',
#   'daughter',
#   'friend',
#   'missing',
#   'takes',
#   'matters',
#   'hands',
#   'police',
#   'pursue',
#   'multiple',
#   'leads',
#   'pressure',
#   'mounts'],
#  ['stark',
#   'perverse',
#   'story',
#   'murder',
#   'kidnapping',
#   'police',
#   'corruption',
#   'mexican',
#   'border',
#   'town'],
#  ['gandhi',
#   'character',
#   'fully',
#   'explained',
#   'man',
#   'nonviolence',
#   'patience',
#   'able',
#   'drive',
#   'british',
#   'subcontinent',
#   'stubborn',
#   'nature',
#   'jinnah',
#   'commitment',
#   'towards',
#   'pakistan',
#   'portrayed'],
#  ['wife',
#   'mistress',
#   'cruel',
#   'headmaster',
#   'conspire',
#   'kill',
#   'murder',
#   'committed',
#   'corpse',
#   'disappears',
#   'strange',
#   'events',
#   'begin',
#   'plague',
#   'two',
#   'women'],
#  ['neurotic',
#   'new',
#   'york',
#   'comedian',
#   'alvy',
#   'singer',
#   'falls',
#   'love',
#   'ditzy',
#   'annie',
#   'hall'],
#  ['story',
#   'frank',
#   'abagnale',
#   'birthday',
#   'successfully',
#   'forged',
#   'millions',
#   'dollars',
#   'worth',
#   'checks',
#   'posing',
#   'pan',
#   'pilot',
#   'doctor',
#   'legal',
#   'prosecutor',
#   'seasoned',
#   'dedicated',
#   'fbi',
#   'agent',
#   'pursues'],
#  ['troubled',
#   'teenager',
#   'plagued',
#   'visions',
#   'man',
#   'large',
#   'rabbit',
#   'suit',
#   'manipulates',
#   'commit',
#   'series',
#   'crimes',
#   'narrowly',
#   'escapes',
#   'bizarre',
#   'accident'],
#  ['order',
#   'power',
#   'city',
#   'monsters',
#   'scare',
#   'children',
#   'scream',
#   'however',
#   'children',
#   'toxic',
#   'monsters',
#   'child',
#   'gets',
#   'monsters',
#   'realize',
#   'things',
#   'may',
#   'think'],
#  ['three',
#   'unemployed',
#   'men',
#   'find',
#   'answer',
#   'money',
#   'problems',
#   'recieve',
#   'call',
#   'kidnapper',
#   'however',
#   'things',
#   'planned'],
#  ['jason',
#   'bourne',
#   'dodges',
#   'ruthless',
#   'cia',
#   'official',
#   'agents',
#   'new',
#   'assassination',
#   'program',
#   'searching',
#   'origins',
#   'life',
#   'trained',
#   'killer'],
#  ['seemingly',
#   'indestructible',
#   'humanoid',
#   'cyborg',
#   'sent',
#   'assassinate',
#   'waitress',
#   'whose',
#   'unborn',
#   'son',
#   'lead',
#   'humanity',
#   'war',
#   'machines',
#   'soldier',
#   'war',
#   'sent',
#   'protect',
#   'costs'],
#  ['harried', 'movie', 'director', 'retreats', 'memories', 'fantasies'],
#  ['dorothy',
#   'gale',
#   'swept',
#   'away',
#   'farm',
#   'kansas',
#   'magical',
#   'land',
#   'tornado',
#   'embarks',
#   'quest',
#   'new',
#   'friends',
#   'see',
#   'wizard',
#   'help',
#   'return',
#   'home',
#   'kansas',
#   'help',
#   'friends',
#   'well'],
#  ['irish',
#   'rogue',
#   'wins',
#   'heart',
#   'rich',
#   'widow',
#   'assumes',
#   'dead',
#   'husband',
#   'aristocratic',
#   'position',
#   'century',
#   'england'],
#  ['weatherman', 'finds', 'inexplicably', 'living', 'day'],
#  ['hours',
#   'lives',
#   'three',
#   'young',
#   'men',
#   'french',
#   'suburbs',
#   'day',
#   'violent',
#   'riot'],
#  ['future',
#   'world',
#   'devastated',
#   'disease',
#   'convict',
#   'sent',
#   'back',
#   'time',
#   'gather',
#   'information',
#   'man',
#   'made',
#   'virus',
#   'wiped',
#   'human',
#   'population',
#   'planet'],
#  ['giant',
#   'great',
#   'white',
#   'shark',
#   'arrives',
#   'shores',
#   'new',
#   'england',
#   'beach',
#   'resort',
#   'wreaks',
#   'havoc',
#   'bloody',
#   'attacks',
#   'swimmers',
#   'local',
#   'sheriff',
#   'teams',
#   'marine',
#   'biologist',
#   'old',
#   'seafarer',
#   'hunt',
#   'monster'],
#  ['story',
#   'mole',
#   'police',
#   'department',
#   'undercover',
#   'cop',
#   'objectives',
#   'find',
#   'mole',
#   'cop'],
#  ['three',
#   'world',
#   'war',
#   'veterans',
#   'return',
#   'home',
#   'small',
#   'town',
#   'america',
#   'discover',
#   'families',
#   'irreparably',
#   'changed'],
#  ['clash',
#   'sultan',
#   'shahid',
#   'khan',
#   'leads',
#   'expulsion',
#   'khan',
#   'wasseypur',
#   'ignites',
#   'deadly',
#   'blood',
#   'feud',
#   'spanning',
#   'three',
#   'generations'],
#  ['aspiring',
#   'author',
#   'civil',
#   'rights',
#   'movement',
#   'decides',
#   'write',
#   'book',
#   'detailing',
#   'african',
#   'american',
#   'maids',
#   'point',
#   'view',
#   'white',
#   'families',
#   'work',
#   'hardships',
#   'daily',
#   'basis'],
#  ['young',
#   'woman',
#   'whose',
#   'father',
#   'imprisoned',
#   'terrifying',
#   'beast',
#   'offers',
#   'place',
#   'unaware',
#   'captor',
#   'actually',
#   'prince',
#   'physically',
#   'altered',
#   'magic',
#   'spell'],
#  ['man',
#   'robs',
#   'bank',
#   'pay',
#   'lover',
#   'operation',
#   'turns',
#   'hostage',
#   'situation',
#   'media',
#   'circus'],
#  ['fear',
#   'violence',
#   'escalate',
#   'people',
#   'algiers',
#   'fight',
#   'independence',
#   'french',
#   'government'],
#  ['two',
#   'neighbors',
#   'woman',
#   'man',
#   'form',
#   'strong',
#   'bond',
#   'suspect',
#   'extramarital',
#   'activities',
#   'spouses',
#   'however',
#   'agree',
#   'keep',
#   'bond',
#   'platonic',
#   'commit',
#   'similar',
#   'wrongs'],
#  ['blacksmith',
#   'turner',
#   'teams',
#   'eccentric',
#   'pirate',
#   'captain',
#   'jack',
#   'sparrow',
#   'save',
#   'love',
#   'governor',
#   'daughter',
#   'jack',
#   'former',
#   'pirate',
#   'allies',
#   'undead'],
#  ['former',
#   'child',
#   'star',
#   'torments',
#   'paraplegic',
#   'sister',
#   'decaying',
#   'hollywood',
#   'mansion'],
#  ['travis',
#   'henderson',
#   'aimless',
#   'drifter',
#   'missing',
#   'four',
#   'years',
#   'wanders',
#   'desert',
#   'must',
#   'reconnect',
#   'society',
#   'life',
#   'family'],
#  ['desperate',
#   'measures',
#   'taken',
#   'man',
#   'tries',
#   'save',
#   'family',
#   'dark',
#   'side',
#   'law',
#   'commit',
#   'unexpected',
#   'crime'],
#  ['stranger',
#   'city',
#   'asks',
#   'questions',
#   'one',
#   'asked',
#   'childlike',
#   'curiosity',
#   'take',
#   'journey',
#   'love',
#   'laughter',
#   'letting']]

# %%
df['clean_plot'] = plot

# %%
df['clean_plot']
# Out:
# 0      [two, imprisoned, men, bond, number, years, fi...
# 1      [aging, patriarch, organized, crime, dynasty, ...
# 2      [early, life, career, vito, corleone, new, yor...
# 3      [menace, known, joker, emerges, mysterious, pa...
# 4      [jury, holdout, attempts, prevent, miscarriage...
#                              ...
# 245    [blacksmith, turner, teams, eccentric, pirate,...
# 246    [former, child, star, torments, paraplegic, si...
# 247    [travis, henderson, aimless, drifter, missing,...
# 248    [desperate, measures, taken, man, tries, save,...
# 249    [stranger, city, asks, questions, one, asked, ...
# Name: clean_plot, Length: 250, dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0                     Title  Year     Rated     Released  Runtime  \
# 0           1  The Shawshank Redemption  1994         R  14 Oct 1994  142 min
# 1           2             The Godfather  1972         R  24 Mar 1972  175 min
# 2           3    The Godfather: Part II  1974         R  20 Dec 1974  202 min
# 3           4           The Dark Knight  2008     PG-13  18 Jul 2008  152 min
# 4           5              12 Angry Men  1957  APPROVED  01 Apr 1957   96 min
#
#                   Genre              Director  \
# 0          Crime, Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2          Crime, Drama  Francis Ford Coppola
# 3  Action, Crime, Drama     Christopher Nolan
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0  Stephen King (short story "Rita Hayworth and S...
# 1  Mario Puzo (screenplay), Francis Ford Coppola ...
# 2  Francis Ford Coppola (screenplay), Mario Puzo ...
# 3  Jonathan Nolan (screenplay), Christopher Nolan...
# 4  Reginald Rose (story), Reginald Rose (screenplay)
#
#                                               Actors  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Marlon Brando, Al Pacino, James Caan, Richard ...
# 2  Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 3  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
#
#                                                 Plot  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  The early life and career of Vito Corleone in ...
# 3  When the menace known as the Joker emerges fro...
# 4  A jury holdout attempts to prevent a miscarria...
#
#                                      Language  Country  \
# 0                                     English      USA
# 1                     English, Italian, Latin      USA
# 2  English, Italian, Spanish, Latin, Sicilian      USA
# 3                           English, Mandarin  USA, UK
# 4                                     English      USA
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. Another 19 wins & 30 n...
# 1    Won 3 Oscars. Another 23 wins & 27 nominations.
# 2    Won 6 Oscars. Another 10 wins & 20 nominations.
# 3  Won 2 Oscars. Another 151 wins & 153 nominations.
# 4  Nominated for 3 Oscars. Another 16 wins & 8 no...
#
#                                               Poster           Ratings.Source  \
# 0  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 1  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 2  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 3  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 4  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
#
#   Ratings.Value  Metascore  imdbRating  imdbVotes     imdbID   Type  \
# 0        9.3/10       80.0         9.3    1825626  tt0111161  movie
# 1        9.2/10      100.0         9.2    1243444  tt0068646  movie
# 2        9.0/10       85.0         9.0     856870  tt0071562  movie
# 3        9.0/10       82.0         9.0    1802351  tt0468569  movie
# 4        8.9/10       96.0         8.9     494215  tt0050083  movie
#
#    tomatoMeter  tomatoImage  tomatoRating  tomatoReviews  tomatoFresh  \
# 0          NaN          NaN           NaN            NaN          NaN
# 1          NaN          NaN           NaN            NaN          NaN
# 2          NaN          NaN           NaN            NaN          NaN
# 3          NaN          NaN           NaN            NaN          NaN
# 4          NaN          NaN           NaN            NaN          NaN
#
#    tomatoRotten  tomatoConsensus  tomatoUserMeter  tomatoUserRating  \
# 0           NaN              NaN              NaN               NaN
# 1           NaN              NaN              NaN               NaN
# 2           NaN              NaN              NaN               NaN
# 3           NaN              NaN              NaN               NaN
# 4           NaN              NaN              NaN               NaN
#
#    tomatoUserReviews                                          tomatoURL  \
# 0                NaN  http://www.rottentomatoes.com/m/shawshank_rede...
# 1                NaN         http://www.rottentomatoes.com/m/godfather/
# 2                NaN  http://www.rottentomatoes.com/m/godfather_part...
# 3                NaN   http://www.rottentomatoes.com/m/the_dark_knight/
# 4                NaN  http://www.rottentomatoes.com/m/1000013-12_ang...
#
#            DVD     BoxOffice                       Production  \
# 0  27 Jan 1998           NaN                Columbia Pictures
# 1  09 Oct 2001           NaN               Paramount Pictures
# 2  24 May 2005           NaN               Paramount Pictures
# 3  09 Dec 2008  $533,316,061  Warner Bros. Pictures/Legendary
# 4  06 Mar 2001           NaN             Criterion Collection
#
#                                              Website  Response  \
# 0                                                NaN      True
# 1                        http://www.thegodfather.com      True
# 2                       http://www.thegodfather.com/      True
# 3               http://thedarkknight.warnerbros.com/      True
# 4  http://www.criterion.com/films/27871-12-angry-men      True
#
#                                           clean_plot
# 0  [two, imprisoned, men, bond, number, years, fi...
# 1  [aging, patriarch, organized, crime, dynasty, ...
# 2  [early, life, career, vito, corleone, new, yor...
# 3  [menace, known, joker, emerges, mysterious, pa...
# 4  [jury, holdout, attempts, prevent, miscarriage...

# %%
df['Genre'] = df['Genre'].apply(lambda x: x.split(','))
df['Actors'] = df['Actors'].apply(lambda x: x.split(',')[:4])
df['Director'] = df['Director'].apply(lambda x: x.split(','))

# %%
df['Actors'][1]
# Out:
# ['Marlon Brando', ' Al Pacino', ' James Caan', ' Richard S. Castellano']

# %%
def clean(sentence):
    temp = []
    for word in sentence:
        temp.append(word.lower().replace(' ', ''))
    return temp

# %%
df['Genre'] = [clean(x) for x in df['Genre']]
df['Actors'] = [clean(x) for x in df['Actors']]
df['Director'] = [clean(x) for x in df['Director']]
df['Actors'][1]
# Out:
# ['marlonbrando', 'alpacino', 'jamescaan', 'richards.castellano']

# %%
# combining all the columns data
columns = ['clean_plot', 'Genre', 'Actors', 'Director']
l = []
for i in range(len(df)):
    words = ''
    for col in columns:
        words += ' '.join(df[col][i]) + ' '
    l.append(words)
l
# Out:
# ['two imprisoned men bond number years finding solace eventual redemption acts common decency crime drama timrobbins morganfreeman bobgunton williamsadler frankdarabont ',
#  'aging patriarch organized crime dynasty transfers control clandestine empire reluctant son crime drama marlonbrando alpacino jamescaan richards.castellano francisfordcoppola ',
#  'early life career vito corleone new york portrayed son michael expands tightens grip family crime syndicate crime drama alpacino robertduvall dianekeaton robertdeniro francisfordcoppola ',
#  'menace known joker emerges mysterious past wreaks havoc chaos people gotham dark knight must accept one greatest psychological physical tests ability fight injustice action crime drama christianbale heathledger aaroneckhart michaelcaine christophernolan ',
#  'former child star torments paraplegic sister decaying hollywood mansion drama horror thriller bettedavis joancrawford victorbuono wesleyaddy robertaldrich ',
#  'travis henderson aimless drifter missing four years wanders desert must reconnect society life family drama harrydeanstanton samberry bernhardwicki deanstockwell wimwenders ',
#  'desperate measures taken man tries save family dark side law commit unexpected crime crime drama mystery ajaydevgn shriyasaran tabu rajatkapoor nishikantkamat ',
#  'stranger city asks questions one asked childlike curiosity take journey love laughter letting comedy drama fantasy aamirkhan anushkasharma sanjaydutt bomanirani rajkumarhirani ']

# %%
df['clean_input'] = l
df = df[['Title', 'clean_input']]
df.head()
# Out:
#                       Title                                        clean_input
# 0  The Shawshank Redemption  two imprisoned men bond number years finding s...
# 1             The Godfather  aging patriarch organized crime dynasty transf...
# 2    The Godfather: Part II  early life career vito corleone new york portr...
# 3           The Dark Knight  menace known joker emerges mysterious past wre...
# 4              12 Angry Men  jury holdout attempts prevent miscarriage just...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
tfidf = TfidfVectorizer()
features = tfidf.fit_transform(df['clean_input'])

# %%
# create cosine similarity matrix
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(features, features)
print(cosine_sim)
# Out:
# [[1.         0.02678083 0.02577716 ... 0.03951546 0.02753552 0.00336651]
#  [0.02678083 1.         0.17542882 ... 0.00345231 0.05241316 0.0034233 ]
#  [0.02577716 0.17542882 1.         ... 0.04315335 0.07138058 0.00329501]
#  ...
#  [0.03951546 0.00345231 0.04315335 ... 1.         0.02507045 0.00338774]
#  [0.02753552 0.05241316 0.07138058 ... 0.02507045 1.         0.00351977]
#  [0.00336651 0.0034233  0.00329501 ... 0.00338774 0.00351977 1.        ]]

# %%
index = pd.Series(df['Title'])
index.head()
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2      The Godfather: Part II
# 3             The Dark Knight
# 4                12 Angry Men
# Name: Title, dtype: object

# %%
def recommend_movies(title):
    movies = []
    idx = index[index == title].index[0]
    # print(idx)
    score = pd.Series(cosine_sim[idx]).sort_values(ascending=False)
    top10 = list(score.iloc[1:11].index)
    # print(top10)
    
    for i in top10:
        movies.append(df['Title'][i])
    return movies

# %%
recommend_movies('Die Hard')
# Out:
# ['La La Land',
#  'Drishyam',
#  'The Dark Knight Rises',
#  'The Great Escape',
#  'The Sixth Sense',
#  'Terminator 2: Judgment Day',
#  'Django Unchained',
#  'The Third Man',
#  'Twelve Monkeys',
#  'The Great Dictator']

# %%
pd.Series(cosine_sim[3]).sort_values(ascending=False)
# Out:
# 3      1.000000
# 113    0.193484
# 62     0.192231
# 47     0.127716
# 243    0.073168
#          ...
# 60     0.000000
# 226    0.000000
# 205    0.000000
# 115    0.000000
# 184    0.000000
# Length: 250, dtype: float64

# %%
recommend_movies('Django Unchained')
# Out:
# ['For a Few Dollars More',
#  'Inglourious Basterds',
#  'The Good, the Bad and the Ugly',
#  'Casino',
#  'Pulp Fiction',
#  'Unforgiven',
#  'The Treasure of the Sierra Madre',
#  'The Dark Knight Rises',
#  'Munna Bhai M.B.B.S.',
#  'Star Wars: Episode VI - Return of the Jedi']
